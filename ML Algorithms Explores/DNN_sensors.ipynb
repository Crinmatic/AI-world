# %%
import matplotlib.pyplot as plt
from math import sqrt
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
# load the data
data = (r'C:\Users\King alagbe\Documents\sensor.csv')
df = pd.read_csv(data)

# %%
# Drop the columns that are useless
col = df.drop( columns = ['timestamp' , 'sensor_15'] , axis = 1)
col.head(2)
# Out:
#    Unnamed: 0  sensor_00  sensor_01  sensor_02  sensor_03  sensor_04  \
# 0           0   2.465394   47.09201    53.2118   46.31076    634.375
# 1           1   2.465394   47.09201    53.2118   46.31076    634.375
#
#    sensor_05  sensor_06  sensor_07  sensor_08  ...  sensor_43  sensor_44  \
# 0   76.45975   13.41146   16.13136   15.56713  ...   41.92708    39.6412
# 1   76.45975   13.41146   16.13136   15.56713  ...   41.92708    39.6412
#
#    sensor_45  sensor_46  sensor_47  sensor_48  sensor_49  sensor_50  \
# 0   65.68287   50.92593   38.19444   157.9861   67.70834   243.0556
# 1   65.68287   50.92593   38.19444   157.9861   67.70834   243.0556
#
#    sensor_51  machine_status
# 0   201.3889          NORMAL
# 1   201.3889          NORMAL
#
# [2 rows x 53 columns]

# %%
# Encode the "machine_status" column
from sklearn.preprocessing import LabelEncoder
machine_stats = LabelEncoder()
col['machine_stat'] = machine_stats.fit_transform(col['machine_status'] )

# %%
# Check for missing data
miss_data = col.isnull().sum()

# %%
col.append(['machine_stat'])
col.head()
# Out:
#    Unnamed: 0  sensor_00  sensor_01  sensor_02  sensor_03  sensor_04  \
# 0           0   2.465394   47.09201    53.2118  46.310760   634.3750
# 1           1   2.465394   47.09201    53.2118  46.310760   634.3750
# 2           2   2.444734   47.35243    53.2118  46.397570   638.8889
# 3           3   2.460474   47.09201    53.1684  46.397568   628.1250
# 4           4   2.445718   47.13541    53.2118  46.397568   636.4583
#
#    sensor_05  sensor_06  sensor_07  sensor_08  ...  sensor_44  sensor_45  \
# 0   76.45975   13.41146   16.13136   15.56713  ...  39.641200   65.68287
# 1   76.45975   13.41146   16.13136   15.56713  ...  39.641200   65.68287
# 2   73.54598   13.32465   16.03733   15.61777  ...  39.351852   65.39352
# 3   76.98898   13.31742   16.24711   15.69734  ...  39.062500   64.81481
# 4   76.58897   13.35359   16.21094   15.69734  ...  38.773150   65.10416
#
#    sensor_46  sensor_47  sensor_48  sensor_49  sensor_50  sensor_51  \
# ...

# %%
del col['machine_status']

# %%
col.shape
# Out:
# (220320, 53)

# %%
for miss_data in col:
    miss_sensors = col[miss_data].astype(float).mean(axis=0)
    print("mean_sensor" , "of" , miss_data , "=" , miss_sensors )
    col[miss_data].replace(np.nan , miss_sensors , inplace = True)
# Out:
# mean_sensor of Unnamed: 0 = 110159.5
# mean_sensor of sensor_00 = 2.3722208156081623
# mean_sensor of sensor_01 = 47.59161070051828
# mean_sensor of sensor_02 = 50.86739214871566
# mean_sensor of sensor_03 = 43.752481029367594
# mean_sensor of sensor_04 = 590.6739358978197
# mean_sensor of sensor_05 = 73.39641389272629
# mean_sensor of sensor_06 = 13.501537443828683
# mean_sensor of sensor_07 = 15.843151868847537
# mean_sensor of sensor_08 = 15.200721267392854
# mean_sensor of sensor_09 = 14.799209606885523
# mean_sensor of sensor_10 = 41.4703390156575
# mean_sensor of sensor_11 = 41.91831905986677
# mean_sensor of sensor_12 = 29.13697472318412
# mean_sensor of sensor_13 = 7.078857517628702
# mean_sensor of sensor_14 = 376.8600409188042
# mean_sensor of sensor_16 = 416.4728920589373
# mean_sensor of sensor_17 = 421.1275168968804
# mean_sensor of sensor_18 = 2.303784945820336
# mean_sensor of sensor_19 = 590.8297752058146
# mean_sensor of sensor_20 = 360.80516520640543
# ...

# %%
#normalize data
col['sensor_00'] = col['sensor_00']/col['sensor_00'].max()
col['sensor_01'] = col['sensor_01']/col['sensor_01'].max()
col['sensor_02'] = col['sensor_02']/col['sensor_02'].max()
col['sensor_03'] = col['sensor_03']/col['sensor_03'].max()
col['sensor_04'] = col['sensor_04']/col['sensor_04'].max()
col['sensor_05'] = col['sensor_05']/col['sensor_05'].max()
col['sensor_06'] = col['sensor_06']/col['sensor_06'].max()
col['sensor_07'] = col['sensor_07']/col['sensor_07'].max()
col['sensor_08'] = col['sensor_08']/col['sensor_08'].max()
col['sensor_09'] = col['sensor_09']/col['sensor_09'].max()
col['sensor_10'] = col['sensor_10']/col['sensor_10'].max()
col['sensor_11'] = col['sensor_11']/col['sensor_11'].max()
col['sensor_12'] = col['sensor_12']/col['sensor_12'].max()
col['sensor_13'] = col['sensor_13']/col['sensor_13'].max()
col['sensor_14'] = col['sensor_14']/col['sensor_14'].max()
col['sensor_16'] = col['sensor_16']/col['sensor_16'].max()
col['sensor_17'] = col['sensor_17']/col['sensor_17'].max()
col['sensor_18'] = col['sensor_18']/col['sensor_18'].max()
col['sensor_19'] = col['sensor_19']/col['sensor_19'].max()
col['sensor_20'] = col['sensor_20']/col['sensor_20'].max()
col['sensor_21'] = col['sensor_21']/col['sensor_21'].max()
col['sensor_22'] = col['sensor_22']/col['sensor_22'].max()
col['sensor_23'] = col['sensor_23']/col['sensor_23'].max()
col['sensor_24'] = col['sensor_24']/col['sensor_24'].max()
col['sensor_25'] = col['sensor_25']/col['sensor_25'].max()
col['sensor_26'] = col['sensor_26']/col['sensor_26'].max()
col['sensor_27'] = col['sensor_27']/col['sensor_27'].max()
col['sensor_28'] = col['sensor_28']/col['sensor_28'].max()
col['sensor_29'] = col['sensor_29']/col['sensor_29'].max()
col['sensor_30'] = col['sensor_30']/col['sensor_30'].max()
col['sensor_31'] = col['sensor_31']/col['sensor_31'].max()
col['sensor_32'] = col['sensor_32']/col['sensor_32'].max()
col['sensor_33'] = col['sensor_33']/col['sensor_33'].max()
col['sensor_34'] = col['sensor_34']/col['sensor_34'].max()
col['sensor_35'] = col['sensor_35']/col['sensor_35'].max()
col['sensor_36'] = col['sensor_36']/col['sensor_36'].max()
col['sensor_37'] = col['sensor_37']/col['sensor_37'].max()
col['sensor_38'] = col['sensor_38']/col['sensor_38'].max()
col['sensor_39'] = col['sensor_39']/col['sensor_39'].max()
col['sensor_40'] = col['sensor_40']/col['sensor_40'].max()
col['sensor_41'] = col['sensor_41']/col['sensor_41'].max()
col['sensor_42'] = col['sensor_42']/col['sensor_42'].max()
col['sensor_43'] = col['sensor_43']/col['sensor_43'].max()
col['sensor_44'] = col['sensor_44']/col['sensor_44'].max()
col['sensor_45'] = col['sensor_45']/col['sensor_45'].max()
col['sensor_46'] = col['sensor_46']/col['sensor_46'].max()
col['sensor_47'] = col['sensor_47']/col['sensor_47'].max()
col['sensor_48'] = col['sensor_48']/col['sensor_48'].max()
col['sensor_49'] = col['sensor_49']/col['sensor_49'].max()
col['sensor_50'] = col['sensor_50']/col['sensor_50'].max()
col['sensor_51'] = col['sensor_51']/col['sensor_51'].max()
col.describe()
# Out:
#           Unnamed: 0      sensor_00      sensor_01      sensor_02  \
# count  220320.000000  220320.000000  220320.000000  220320.000000
# mean   110159.500000       0.930642       0.838952       0.907811
# std     63601.049991       0.157929       0.058065       0.065438
# min         0.000000       0.000000       0.000000       0.591789
# 25%     55079.750000       0.949054       0.816373       0.899303
# 50%    110159.500000       0.963335       0.848508       0.921766
# 75%    165239.250000       0.980702       0.872226       0.941905
# max    220319.000000       1.000000       1.000000       1.000000
#
#            sensor_03      sensor_04      sensor_05      sensor_06  \
# count  220320.000000  220320.000000  220320.000000  220320.000000
# mean        0.907342       0.738342       0.733965       0.606779
# std         0.050161       0.180022       0.172975       0.096177
# min         0.656165       0.003498       0.000000       0.000650
# ...

# %%
#split your data to X and Y
X = col[['sensor_00' , 'sensor_01' , 'sensor_02' ,'sensor_03' ,'sensor_04' ,'sensor_05' ,'sensor_06' ,'sensor_07' ,'sensor_08' ,'sensor_09' ,'sensor_10' ,'sensor_11' ,'sensor_12' ,'sensor_13' ,'sensor_14' ,'sensor_16' ,'sensor_17' ,'sensor_18' ,'sensor_19' ,'sensor_20' ,'sensor_21' ,'sensor_22' ,'sensor_23' ,'sensor_24' ,'sensor_25' ,'sensor_26' ,'sensor_27' ,'sensor_28' ,'sensor_29' ,'sensor_30' ,'sensor_31' ,'sensor_01' ,'sensor_32' ,'sensor_33' ,'sensor_34' ,'sensor_35' ,'sensor_36' ,'sensor_37' ,'sensor_38' ,'sensor_39' ,'sensor_40' ,'sensor_41' ,'sensor_42' ,'sensor_43' ,'sensor_44' ,'sensor_45' ,'sensor_46' ,'sensor_47' ,'sensor_48' ,'sensor_49' ,'sensor_50' ,'sensor_51' ]].values
Y = col['machine_stat'].values

# %%
# Check for the sizes
X_train , X_test , Y_train ,Y_test = train_test_split(X , Y , test_size = 0.20 , random_state = 40)
print(X_train.shape); print(X_test.shape)
# Out:
# (176256, 52)
# (44064, 52)

# %%
# This is used for classification, It detects the amount of classes in a target
Y_train = to_categorical(Y_train)
Y_test = to_categorical(Y_test)

count_classes = Y_test.shape[1]
print(count_classes)
# Out:
# 3

# %%
# Input the parameters for training the model
model = Sequential()

model.add(Dense(200, activation = "relu" , input_dim = 52))
model.add(Dense(100,  activation = "relu") )
model.add(Dense(100,  activation = "relu") )
model.add(Dense(50 , activation = "relu"))
model.add(Dense(25 , activation = "relu"))

model.add(Dense(3, activation = "softmax")) 
#compile the model
model.compile(optimizer = 'adam', loss= 'categorical_crossentropy' ,metrics=['accuracy'])

# %%
#build the model
model.fit(X_train ,Y_train, epochs = 10)
# Out:
# Epoch 1/10
# 176256/176256 [==============================] - 48s 273us/step - loss: 0.0143 - accuracy: 0.9955
# Epoch 2/10
# 176256/176256 [==============================] - 25s 144us/step - loss: 0.0061 - accuracy: 0.9981
# Epoch 3/10
# 176256/176256 [==============================] - 24s 137us/step - loss: 0.0047 - accuracy: 0.9986
# Epoch 4/10
# 176256/176256 [==============================] - 24s 135us/step - loss: 0.0042 - accuracy: 0.9987
# Epoch 5/10
# 176256/176256 [==============================] - 24s 137us/step - loss: 0.0038 - accuracy: 0.9990
# Epoch 6/10
# 176256/176256 [==============================] - 23s 133us/step - loss: 0.0036 - accuracy: 0.9990
# Epoch 7/10
# 176256/176256 [==============================] - 25s 142us/step - loss: 0.0035 - accuracy: 0.9991
# Epoch 8/10
# 176256/176256 [==============================] - 25s 139us/step - loss: 0.0037 - accuracy: 0.9991
# Epoch 9/10
# ...
