# %%
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
import sklearn

# %%
train = pd.read_csv(r'C:\Users\King alagbe\Downloads\trainn.csv')
test = pd.read_csv(r'C:\Users\King alagbe\Downloads\testt.csv')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
train['insured_education_level'] = le.fit_transform(train['insured_education_level'])
train['insured_occupation'] = le.fit_transform(train['insured_occupation'])
train['insured_relationship'] = le.fit_transform(train['insured_relationship'])
train['authorities_contacted'] = le.fit_transform(train['authorities_contacted'])
train['policy_state'] = le.fit_transform(train['policy_state'])
train['incident_severity'] = le.fit_transform(train['incident_severity'])
train['authorities_contacted'] = le.fit_transform(train['authorities_contacted'])
train['incident_state'] = le.fit_transform(train['incident_state'])
train['incident_city'] = le.fit_transform(train['incident_city'])
train['police_report_available'] = le.fit_transform(train['police_report_available'])
train['auto_make'] = le.fit_transform(train['auto_make'])
train['auto_model'] = le.fit_transform(train['auto_model'])
train['collision_type'] = le.fit_transform(train['collision_type'])
train['property_damage']= le.fit_transform(train['property_damage'])
train['incident_type'] = le.fit_transform(train['incident_type'])

# %%
test['insured_education_level'] = le.fit_transform(test['insured_education_level'])
test['insured_occupation'] = le.fit_transform(test['insured_occupation'])
test['insured_relationship'] = le.fit_transform(test['insured_relationship'])
test['authorities_contacted'] = le.fit_transform(test['authorities_contacted'])
test['policy_state'] = le.fit_transform(test['policy_state'])
test['incident_severity'] = le.fit_transform(test['incident_severity'])
test['authorities_contacted'] = le.fit_transform(test['authorities_contacted'])
test['incident_state'] = le.fit_transform(test['incident_state'])
test['incident_city'] = le.fit_transform(test['incident_city'])
test['police_report_available'] = le.fit_transform(test['police_report_available'])
test['auto_make'] = le.fit_transform(test['auto_make'])
test['auto_model'] = le.fit_transform(test['auto_model'])
test['collision_type'] = le.fit_transform(test['collision_type'])
test['property_damage']= le.fit_transform(test['property_damage'])
test['incident_type'] = le.fit_transform(test['incident_type'])

# %%
train.head
# Out:
# <bound method NDFrame.head of       Customer_ID  months_as_customer  age insured_sex  \
# 0    Customer_541                 239   41      FEMALE
# 1    Customer_440                 108   31        MALE
# 2    Customer_482                 116   30        MALE
# 3    Customer_422                   8   21        MALE
# 4    Customer_778                 161   38        MALE
# ..            ...                 ...  ...         ...
# 695  Customer_106                 464   61      FEMALE
# 696  Customer_270                 369   55        MALE
# 697  Customer_860                 230   42      FEMALE
# 698  Customer_435                 102   28        MALE
# 699  Customer_102                 279   41      FEMALE
#
#      insured_education_level  insured_occupation insured_hobbies  \
# 0                          3                   4       paintball
# 1                          5                  10        yachting
# 2                          3                   5            golf
# 3                          2                   5          hiking
# 4                          6                   8        exercise
# ..                       ...                 ...             ...
# 695                        0                   9      basketball
# 696                        1                   5         camping
# 697                        4                   0            golf
# 698                        4                   6         reading
# 699                        3                   9  bungie-jumping
#
#      insured_relationship  capital-gains  capital-loss  ...  \
# 0                       2          51400         -6300  ...
# 1                       1              0             0  ...
# 2                       1              0        -35500  ...
# 3                       0              0             0  ...
# 4                       1          60200             0  ...
# ..                    ...            ...           ...  ...
# 695                     0              0        -56400  ...
# 696                     0          55400             0  ...
# 697                     3              0        -45300  ...
# 698                     5          55200             0  ...
# 699                     0          37300        -31700  ...
#
#      authorities_contacted incident_state  incident_city witnesses  \
# 0                        4              0              0         2
# 1                        1              1              1         2
# 2                        3              6              5         3
# 3                        3              6              1         0
# 4                        4              6              6         2
# ..                     ...            ...            ...       ...
# 695                      4              5              3         2
# 696                      4              5              0         0
# 697                      3              1              3         2
# 698                      4              3              3         0
# 699                      1              0              4         3
#
#      police_report_available auto_make  auto_model  auto_year  _c39  \
# 0                          2         8          12       2013   NaN
# 1                          1         4          27       2006   NaN
# 2                          0        13          28       2004   NaN
# 3                          0        12          11       2012   NaN
# 4                          2        13          20       2003   NaN
# ..                       ...       ...         ...        ...   ...
# 695                        2        10           3       2000   NaN
# 696                        2        12          18       2003   NaN
# 697                        2         0          23       1999   NaN
# 698                        1         4          27       1996   NaN
# 699                        1         5          16       2013   NaN
#
#      total_claim_amount
# 0              14386.67
# 1              76440.00
# 2              79560.00
# 3             121680.00
# 4              80640.00
# ..                  ...
# 695           106400.00
# 696           113733.33
# 697            78466.67
# 698            97866.67
# 699            38400.00
#
# [700 rows x 37 columns]>

# %%
testX = test.drop(['Customer_ID' , 'insured_sex' , 'insured_hobbies', '_c39', 'policy_bind_date', 'policy_csl', 'incident_location', 'incident_date', ], axis = 1)

# %%
trainY= train['total_claim_amount']
trainX = train.drop(['Customer_ID' , 'insured_sex' , 'insured_hobbies', '_c39', 'policy_bind_date', 'policy_csl', 'incident_location', 'incident_date', ], axis = 1)

# %%
trainX.head()
# Out:
#    months_as_customer  age  insured_education_level  insured_occupation  \
# 0                 239   41                        3                   4
# 1                 108   31                        5                  10
# 2                 116   30                        3                   5
# 3                   8   21                        2                   5
# 4                 161   38                        6                   8
#
#    insured_relationship  capital-gains  capital-loss  policy_number  \
# 0                     2          51400         -6300         743092
# 1                     1              0             0         492224
# 2                     1              0        -35500         996253
# 3                     0              0             0         355085
# 4                     1          60200             0         192524
#
#    policy_state  policy_deductable  ...  incident_severity  \
# 0             2               1000  ...                  3
# 1             1               2000  ...                  2
# 2             1                500  ...                  0
# 3             1                500  ...                  0
# 4             0               2000  ...                  2
#
#    authorities_contacted  incident_state  incident_city  witnesses  \
# 0                      4               0              0          2
# 1                      1               1              1          2
# 2                      3               6              5          3
# 3                      3               6              1          0
# 4                      4               6              6          2
#
#    police_report_available  auto_make  auto_model  auto_year  \
# 0                        2          8          12       2013
# 1                        1          4          27       2006
# 2                        0         13          28       2004
# 3                        0         12          11       2012
# 4                        2         13          20       2003
#
#    total_claim_amount
# 0            14386.67
# 1            76440.00
# 2            79560.00
# 3           121680.00
# 4            80640.00
#
# [5 rows x 29 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
names = trainX.iloc[:, 0:30].columns
scaler = MinMaxScaler()
trainX = scaler.fit_transform(trainX.iloc[:, 0:30])
trainX =pd.DataFrame(data=trainX, columns = names)
trainX.head()
# Out:
#    months_as_customer       age  insured_education_level  insured_occupation  \
# 0            0.498956  0.488889                 0.500000            0.307692
# 1            0.225470  0.266667                 0.833333            0.769231
# 2            0.242171  0.244444                 0.500000            0.384615
# 3            0.016701  0.044444                 0.333333            0.384615
# 4            0.336117  0.422222                 1.000000            0.615385
#
#    insured_relationship  capital-gains  capital-loss  policy_number  \
# 0                   0.4       0.520243      0.943294       0.715194
# 1                   0.2       0.000000      1.000000       0.435850
# 2                   0.2       0.000000      0.680468       0.997092
# 3                   0.0       0.000000      1.000000       0.283144
# 4                   0.2       0.609312      1.000000       0.102131
#
#    policy_state  policy_deductable  ...  incident_severity  \
# 0           1.0           0.333333  ...           1.000000
# 1           0.5           1.000000  ...           0.666667
# 2           0.5           0.000000  ...           0.000000
# 3           0.5           0.000000  ...           0.000000
# 4           0.0           1.000000  ...           0.666667
#
#    authorities_contacted  incident_state  incident_city  witnesses  \
# 0                   1.00        0.000000       0.000000   0.666667
# 1                   0.25        0.166667       0.166667   0.666667
# 2                   0.75        1.000000       0.833333   1.000000
# 3                   0.75        1.000000       0.166667   0.000000
# 4                   1.00        1.000000       1.000000   0.666667
#
#    police_report_available  auto_make  auto_model  auto_year  \
# 0                      1.0   0.615385    0.315789       0.90
# 1                      0.5   0.307692    0.710526       0.55
# 2                      0.0   1.000000    0.736842       0.45
# 3                      0.0   0.923077    0.289474       0.85
# 4                      1.0   1.000000    0.526316       0.40
#
#    total_claim_amount
# 0            0.093102
# 1            0.498432
# 2            0.518812
# 3            0.793938
# 4            0.525867
#
# [5 rows x 29 columns]

# %%
model = XGBRegressor()
x = model.fit(trainX, trainY)
# Out:
# [12:35:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
pred = x.predict('testX')
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# <ipython-input-32-376057b751a7> in <module>
# ----> 1 pred = x.predict('testX')
#
# ~\anaconda3\envs\Tensorflow\lib\site-packages\xgboost\sklearn.py in predict(self, data, output_margin, ntree_limit, validate_features)
#     446         """
#     447         # pylint: disable=missing-docstring,invalid-name
# --> 448         test_dmatrix = DMatrix(data, missing=self.missing, nthread=self.n_jobs)
#     449         # get ntree_limit to use - if none specified, default to
#     450         # best_ntree_limit if defined, otherwise 0.
#
# ~\anaconda3\envs\Tensorflow\lib\site-packages\xgboost\core.py in __init__(self, data, label, missing, weight, silent, feature_names, feature_types, nthread)
#     395             _check_call(_LIB.XGDMatrixCreateFromFile(c_str(data),
#     396                                                      ctypes.c_int(silent),
# --> 397                                                      ctypes.byref(handle)))
#     398             self.handle = handle
#     399         elif isinstance(data, scipy.sparse.csr_matrix):
#
# ~\anaconda3\envs\Tensorflow\lib\site-packages\xgboost\core.py in _check_call(ret)
#     174     """
#     175     if ret != 0:
# --> 176         raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#     177
#     178
#
# XGBoostError: [12:35:43] src/io/local_filesys.cc:86: LocalFileSystem.GetPathInfo: testX error: No such file or directory

# %%
# Out:
# 0                    Parked Car
# 1      Single Vehicle Collision
# 2       Multi-vehicle Collision
# 3      Single Vehicle Collision
# 4       Multi-vehicle Collision
#                  ...
# 695     Multi-vehicle Collision
# 696     Multi-vehicle Collision
# 697     Multi-vehicle Collision
# 698    Single Vehicle Collision
# 699     Multi-vehicle Collision
# Name: incident_type, Length: 700, dtype: object
